# %% [markdown]
# # **PUC-Rio | Departamento de Engenharia Industrial**
# # **ENG 4560: Projeto Integrado VI - Distribuição Física**
#
# ---
#
# # **Aula 4 — Modelagem matemática do CVRP (Parte 2)**
# **Prof. Marcello Congro (marcellocongro@puc-rio.br)**
#
# ---
#
# ## 🎯 Estrutura da Aula:
# 1. Carregar instância
# 2. Definir parâmetros logísticos (heterogêneo)
# 3. Construir modelo matemático
# 4. Resolver
# 5. Comparar desempenho
# 6. Interpretar solução
#
# ---
#
# ## 🧠 Ideia central desta aula (por que ela existe?)
#
# Na **Aula 3**, construímos um primeiro modelo para o CVRP e vimos um comportamento clássico quando a formulação ainda está incompleta:
#
# - o solver pode encontrar uma solução "ótima" **com subtours** (ciclos desconectados do depósito).
#
# Nesta **Aula 4**, vamos fazer duas melhorias fundamentais **no modelo** (não no solver):
#
# 1. **Frota heterogênea** (1 VUC + 3 Fiorinos): aproxima a modelagem da operação real.
# 2. **MTZ (Miller–Tucker–Zemlin)**: adiciona conectividade global e **elimina subtours**.
#
# ⚠️ Mensagem-chave: **mais realismo → mais restrições/variáveis → maior custo computacional**.
# Isso prepara o terreno para discutir escalabilidade, limites de métodos exatos e (nas próximas aulas) heurísticas.
#
# ---
#
# ## ✅ O que você deve conseguir responder ao final
#
# 1. Por que "restrições de grau" (entrar/sair 1x) **não** garantem uma rota conectada ao depósito?
# 2. O que o MTZ faz *na prática* e por que ele aumenta a dificuldade computacional?
# 3. Em que sentido a frota heterogênea muda o espaço de decisão do problema?
# 4. Por que uma solução ótima (MILP) pode ser inviável como decisão gerencial se o tempo de solução for alto?
#
# ## **Como trabalhar neste notebook**
#
# Este material foi estruturado como estudo guiado.
#
# Recomenda-se:
#
# 1. Ler antes de executar;
# 2. Discutir em grupo as perguntas indicadas;
# 3. Observar cuidadosamente os tempos de solução.
#
# Evite executar todas as células de uma vez.

# %%
# =====================================================
# (1) PREPARAÇÃO DO AMBIENTE COMPUTACIONAL
# =====================================================

# Nesta disciplina, o solver é apenas o "motor" de otimização.
# O que determina a qualidade/realismo da solução é o MODELO matemático.

# Aqui instalamos o CBC (open-source) para garantir que o notebook rode.
# Se você tiver Gurobi ou CPLEX configurados, vamos usar mais adiante.

# Pergunta:
# um modelo mais realista será mais fácil ou mais difícil de resolver?

# Instala no mesmo ambiente do kernel do Jupyter (Windows, Linux ou Colab).
# O pacote PuLP inclui um executável do CBC que o Pyomo pode utilizar.
# %pip install -q pyomo pulp
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# =====================================================
# (2) LOCALIZAÇÃO DA INSTÂNCIA LOCAL
# =====================================================

# A instância define o problema: nós (depósito + clientes), demandas,
# distâncias e parâmetros já preparados na Aula 2.

# Os arquivos são lidos diretamente da pasta C3; não há upload ou download.
# =====================================================

from pathlib import Path

required_files = (
    "nodes.csv", "D.npy", "Cvar.npy", "q.npy", "s.npy",
    "Tmov_h.npy", "params.json",
)

# O Jupyter pode iniciar na pasta C3, em Projeto_Dis_Fis ou na raiz.
current_dir = Path.cwd().resolve()
candidate_dirs = (
    current_dir,
    current_dir / "C3",
    current_dir / "Projeto_Dis_Fis" / "C3",
)

base_dir = next(
    (folder for folder in candidate_dirs
     if all((folder / name).is_file() for name in required_files)),
    None,
)

if base_dir is None:
    attempted = "\n".join(f"- {folder}" for folder in candidate_dirs)
    raise FileNotFoundError(
        "Não encontrei todos os arquivos locais da instância. "
        f"Pastas verificadas:\n{attempted}"
    )

print(f"Usando os arquivos locais de: {base_dir}")
for name in required_files:
    print(f"- {name}")
# Out:
# Usando os arquivos locais de: C:\Users\Anton\Projeto_Distribuicao_Fisica\Projeto_Dis_Fis\C3
# - nodes.csv
# - D.npy
# - Cvar.npy
# - q.npy
# - s.npy
# - Tmov_h.npy
# - params.json

# %%
# =====================================================
# (3) LEITURA E VALIDAÇÃO DA INSTÂNCIA
# =====================================================

# Antes de modelar, VALIDAMOS os dados.
# Se a base estiver inconsistente, o solver pode:
# - declarar inviabilidade, ou
# - "resolver" algo que não representa a operação real.
#
# Perguntas rápidas (registre suas respostas):
# 1) A demanda total cabe na frota disponível?
# 2) Existem clientes com demanda > capacidade de algum veículo?
# 3) Distâncias e coordenadas parecem plausíveis?
# =====================================================

import numpy as np
import pandas as pd
import json

nodes = pd.read_csv(base_dir / "nodes.csv")
D = np.load(base_dir / "D.npy")
C = np.load(base_dir / "Cvar.npy")
q = np.load(base_dir / "q.npy")
s = np.load(base_dir / "s.npy")
Tmov_h = np.load(base_dir / "Tmov_h.npy")

with (base_dir / "params.json").open(encoding="utf-8") as file:
    params = json.load(file)

n = len(nodes)

assert D.shape == (n,n)
assert C.shape == (n,n)
assert Tmov_h.shape == (n,n)
assert q.shape == (n,)
assert s.shape == (n,)
assert nodes.loc[0,"id"] == 0

print(f"Instância carregada: {n-1} clientes + depósito")
print(f"Dados lidos localmente de: {base_dir}")
# Out:
# Instância carregada: 40 clientes + depósito
# Dados lidos localmente de: C:\Users\Anton\Projeto_Distribuicao_Fisica\Projeto_Dis_Fis\C3

# %%
# ======================================================
# (4) PARÂMETROS LOGÍSTICOS - FROTA HETEROGÊNEA
# ======================================================

# Nesta aula, saímos do cenário homogêneo (Aula 3) e aproximamos da operação:
# - dois tipos de veículo (Fiorino e VUC)
# - capacidades diferentes
# - custos fixos diferentes
#
# Interpretação:
# Q[k]  -> capacidade do tipo k (kg)
# f[k]  -> custo fixo diário do tipo k (R$)
# H     -> limite operacional de jornada (h)
# v_kmh -> velocidade média (km/h)
# T     -> matriz de tempos de viagem (h), derivada de D (km)

# Pergunta (importante):
# Quais riscos operacionais surgem quando a jornada NÃO é imposta diretamente no modelo?

#
# Observe que:
# VUC:
# Maior capacidade
# Maior custo fixo

# Fiorino:
# Menor capacidade
# Menor custo
# =====================================================

# Tipos de veículos
vehicle_types = ["FIO", "VUC"]

Q = {
    "FIO": float(params["VEHICLES"]["Fiorino"]["Q_kg"]),
    "VUC": float(params["VEHICLES"]["VUC"]["Q_kg"]),
}

f = {
    "FIO": float(params["VEHICLES"]["Fiorino"]["custo_fixo_diario"]),
    "VUC": float(params["VEHICLES"]["VUC"]["custo_fixo_diario"]),
}

H = float(params["H_horas"])
v_kmh = float(params["v_kmh"])

# Usaremos H=8h como referência OPERACIONAL e faremos
# uma checagem pós-solução por rota/veículo (validação).

# Usa diretamente a matriz de tempos preparada na Aula 2.
T = Tmov_h

print("Capacidades locais:", Q)
print("Custos fixos locais:", f)
# Out:
# Capacidades locais: {'FIO': 650.0, 'VUC': 3000.0}
# Custos fixos locais: {'FIO': 250.0, 'VUC': 550.0}

# %%
# =====================================================
# (5) CONSTRUÇÃO DO MODELO
# =====================================================

# Conjuntos típicos:
# N -> nós (0 = depósito; 1..n-1 = clientes)
# C -> clientes
# K -> veículos (nesta aula: veículos individuais, ainda que de tipos distintos)
# A -> arcos (i,j,k): decisão de o veículo k ir de i para j
#
# Atenção:
# - na Aula 3, detectávamos subtours.
# - na Aula 4, vamos ELIMINAR subtours (MTZ).
# =====================================================

from pyomo.environ import *

model = ConcreteModel()

model.N = RangeSet(0, n-1)
model.C = RangeSet(1, n-1)
model.K = Set(initialize=vehicle_types)

model.A = [(i,j,k) for i in range(n)
                     for j in range(n)
                     for k in vehicle_types
                     if i != j]

model.x = Var(model.A, domain=Binary)

# Observação:
# Nesta versão, K representa tipos/decisões de frota (simplificação).
# Uma modelagem mais fiel com 3 Fiorinos + 1 VUC exigiria veículos individuais
# (ex.: K = {FIO1, FIO2, FIO3, VUC1}), aumentando o tamanho do modelo.

# %%
# =====================================================
# (6) VARIÁVEIS AUXILIARES (MTZ)
# =====================================================

# u[i,k] é uma variável auxiliar que impõe uma "ordem" de visita do cliente i
# na rota do veículo k. Ela NÃO mede distância; mede posição relativa.
#
# Intuição:
# - se cada cliente tiver uma posição coerente na sequência,
#   não conseguimos formar um ciclo fechado desconectado do depósito.
#
# Orientação:
# - primeiro implemente a versão TODO (aluno)
# - depois compare com o gabarito
# - e, principalmente, ENTENDA o papel dessa variável.

if hasattr(model, "u"):
    model.del_component(model.u)

model.u = Var(model.C, bounds=(1, n-1))

# %%
# =====================================================
# (7) NÚMERO DE VEÍCULOS POR TIPO
# =====================================================
# Em vez de contar quantas saídas existem do depósito,
# introduzimos uma variável binária y[k].

# y[k] = 1 indica que o veículo foi utilizado.

# Isso representa melhor o custo fixo operacional: o veículo é acionado ou não.

# Número de veículos por tipo
def m_expr(model, k):
    return sum(model.x[0,j,k] for j in model.C)

# Variável binária de ativação do veículo
model.y = Var(model.K, domain=Binary)

# =============================================
# TODO (PREENCHA AQUI):
# Se um veículo sai do depósito, ele deve ser ativado.

def activate_vehicle_rule(model, k):
    return m_expr(model, k) <= model.y[k]

# TODO (PREENCHA AQUI:)
# Se o veículo retorna ao depósito,
# ele também deve estar ativado.

def activate_return_rule(model, k):
    return sum(model.x[i,0,k] for i in model.C) <= model.y[k]
# =============================================

model.activate_vehicle = Constraint(model.K, rule=activate_vehicle_rule)
model.activate_return = Constraint(model.K, rule=activate_return_rule)

# %%
# ============================================================
# (8) DISPONIBILIDADE DE FROTA (REALISMO OPERACIONAL)
# ============================================================
#
# Vamos supor que quiséssemos definir uma quantidade específica de VUCs e Fiorinos para o problema (por exemplo, 1 VUC e 3 Fiorinos)
# Da forma como estruturamos o código, as linhas abaixo são ou não são redundantes? Justifique.

# model.limit_vuc = Constraint(expr = model.y["VUC"] <= 1)
# model.limit_fio = Constraint(expr = model.y["FIO"] <= 3)

# %%
# ============================================================
# (9) FUNÇÃO OBJETIVO
# ============================================================

# Agora otimizamos custo total:
# - custo variável (deslocamento) + custo fixo (ativação de veículo)

# Trade-off típico:
# - usar um VUC (custo fixo maior) pode reduzir o número de veículos e viagens
# - usar Fiorinos (custo fixo menor) pode exigir mais rotas/quilometragem

# Pergunta:
# Se o custo fixo do VUC aumentasse muito, o que você espera que a solução faça?

def obj_rule(model):
    travel_cost = sum(C[i,j] * model.x[i,j,k] for (i,j,k) in model.A)
    fixed_cost = sum(f[k] * model.y[k] for k in model.K)
    return travel_cost + fixed_cost

model.obj = Objective(rule=obj_rule, sense=minimize)

# %%
# ============================================================
# (10) RESTRIÇÕES DE ATENDIMENTO (GRAU)
# ============================================================
# Cada cliente deve ser atendido exatamente UMA vez.
#
# Isso significa duas coisas:
#
# (1) Deve existir exatamente UMA saída do cliente (o veículo sai após atendê-lo).
#
# (2) Deve existir exatamente UMA entrada no cliente (algum veículo chega para atendê-lo).
#
# Essas são chamadas RESTRIÇÕES DE GRAU.
#
# Mesmo garantindo:
#   - uma entrada,
#   - uma saída,
#
# ainda podem existir ciclos desconectados do depósito.
#
# Ou seja:
#
# grau local ≠ conectividade global.
#
# É exatamente isso que o MTZ corrigirá depois.
# ============================================================
# SAÍDA ÚNICA POR CLIENTE
# ============================================================
def out_rule(model, i):

    return sum(
        model.x[i, j, k]
        for j in model.N if j != i
        for k in model.K
    ) == 1

model.out = Constraint(model.C, rule=out_rule)
# ============================================================
# ENTRADA ÚNICA POR CLIENTE
# ============================================================
def in_rule(model, j):

    return sum(
        model.x[i, j, k]
        for i in model.N if i != j
        for k in model.K
    ) == 1

model.inn = Constraint(model.C, rule=in_rule)

# %% [markdown]
# ### Pergunta rápida
#
# Se cada cliente possui exatamente uma entrada e uma saída,
# por que ainda podem existir ciclos desconectados?
#
# Discuta com sua equipe antes de continuar.

# %%
# ============================================================
# (11) BALANÇO NO DEPÓSITO
# ============================================================

# Para cada veículo k:
# - o número de saídas do depósito deve igualar o número de retornos
#
# Importante:
# Isso garante consistência no depósito, mas ainda NÃO impede ciclos desconectados
# entre clientes (subtours).

def depot_balance(model, k):
    return sum(model.x[0,j,k] for j in model.C) == \
           sum(model.x[i,0,k] for i in model.C)

model.depot_balance = Constraint(model.K, rule=depot_balance)

# Cada veículo pode iniciar no máximo uma rota.
# Isso evita que o mesmo veículo opere múltiplas rotas independentes.

def single_departure_rule(model, k):
    return sum(model.x[0, j, k] for j in model.C) <= 1

model.single_departure = Constraint(model.K, rule=single_departure_rule)

# Observação:
# Sem esta restrição, o modelo poderia permitir que o mesmo veículo
# iniciasse múltiplas rotas independentes a partir do depósito.

# %%
# ============================================================
# (12) CAPACIDADE AGREGADA HETEROGÊNEA
# ============================================================
# Aqui fazemos um check agregado:
# - demanda total <= capacidade total disponibilizada pelos veículos ativados

# Atenção:
# Esta restrição NÃO impede que uma rota individual transporte
# mais carga do que a capacidade do veículo.
#
# Atenção:
# Isso NÃO garante que cada veículo individualmente respeite sua capacidade.
# (isso exigiria restrições por veículo/rota — o que aumenta ainda mais o modelo)

def capacity_rule(model):
    total_demand = sum(q[i] for i in range(1,n))
    total_capacity = sum(Q[k] * model.y[k] for k in model.K)
    return total_demand <= total_capacity

model.capacity = Constraint(rule=capacity_rule)

# %%
# ============================================================
# (13) CONSERVAÇÃO DE FLUXO POR VEÍCULO (ESSENCIAL NO HETEROGÊNEO)
# ============================================================
# Para cada veículo k e cliente i:
# - tudo que entra em i pelo veículo k deve sair de i pelo mesmo veículo k
#
# Isso força a rota do veículo a ser "contínua localmente".
#
# Mas, de novo:
# conectividade GLOBAL ainda não está garantida → subtours podem surgir.

# ===============================================================
# TODO (ALUNO): implementar fluxo por tipo
# para todo i em C e todo k em K:
# sum_j x[i,j,k] - sum_j x[j,i,k] == 0

def flow_by_type_rule(model, i, k):
  return (
      sum(model.x[i,j,k] for j in model.N if j != i)
      - sum(model.x[j,i,k] for j in model.N if j != i)
      == 0
  )
# ===============================================================

model.flow_by_type = Constraint(model.C, model.K, rule=flow_by_type_rule)

# %%
# ============================================================
# (14) MTZ — ELIMINAÇÃO DE SUBTOURS
# ============================================================
# Agora adicionamos a restrição que faltava na Aula 3: conectividade global.

# Leia com calma:
# u[i] - u[j] + M * x[i,j] <= M-1 (variações equivalentes)

# Interpretação:
# Se o arco i->j é usado, então j deve estar "depois" de i na ordem.

# Perguntas:
# 1) Por que precisamos de um M grande?
# 2) O que acontece se M for pequeno demais?
# 3) Por que isso evita subtours?

# MTZ - ELIMINAÇÃO DE SUBTOURS
# TODO (ALUNO): Implementar restrição MTZ
# u_i - u_j + (n-1)*sum_k x[i,j,k] <= n-2

# Utilizamos uma única variável u[i] compartilhada entre veículos.
# Essa é uma simplificação para reduzir o tamanho do modelo.
#
# Formulações VRP completas podem utilizar u[i,k],
# aumentando significativamente o número de variáveis e restrições.

if hasattr(model, "mtz"):
    model.del_component(model.mtz)

# ===================================
# TODO (ALUNO): Termine de preencher a função
def mtz_rule(model, i, j):
    if i == j:
        return Constraint.Skip  # Auto-arcos não fazem sentido na ordem MTZ
    return (
        model.u[i]
        - model.u[j]
        + (n-1)*sum(model.x[i,j,k] for k in model.K)
        <= n-2
    )
# ===================================

model.mtz = Constraint(model.C, model.C, rule=mtz_rule)

# %%
# ============================================================
# (15) COMPLEXIDADE — MEDINDO O TAMANHO DO PROBLEMA
# ============================================================

# Queremos ter noção de:
# - número de variáveis binárias
# - número de clientes
# - número de tipos/veículos

# Compare com a Aula 3:
# só acrescentar dimensão de veículo + MTZ já muda muito a escala.

print("Variáveis binárias:", len(model.A))
print("Clientes:", n-1)
print("Tipos de veículos:", vehicle_types)
print("Número de restrições:", len(list(model.component_data_objects(Constraint))))
# Out:
# Variáveis binárias: 3280
# Clientes: 40
# Tipos de veículos: ['FIO', 'VUC']
# Número de restrições: 1729

# %%
# ============================================================
# (16) ESCOLHA DO SOLVER
# ============================================================
# Você pode rodar com CBC, mas para instâncias maiores o Gurobi tende a ser
# significativamente mais rápido.
#
# Observação pedagógica:
# Solver "melhor" ajuda, mas não anula o crescimento combinatório.

from pyomo.opt import SolverFactory

SOLVER_NAME = "cbc"  # opções: cbc, gurobi_direct, cplex
TIME_LIMIT = 1e20  # segundos

# No Windows, informa explicitamente o CBC incluído no PuLP.
if SOLVER_NAME == "cbc":
    import pulp
    solver = SolverFactory("cbc", executable=pulp.PULP_CBC_CMD().path)
else:
    solver = SolverFactory(SOLVER_NAME)

if not solver.available(exception_flag=False):
    raise RuntimeError(f"Solver {SOLVER_NAME} não disponível.")

time_limit_option = {
    "cbc": "seconds",
    "gurobi_direct": "TimeLimit",
    "cplex": "timelimit",
}
solver.options[time_limit_option[SOLVER_NAME]] = TIME_LIMIT
print(f"Solver {SOLVER_NAME} disponível; limite: {TIME_LIMIT} s.")
# Out:
# Solver cbc disponível; limite: 60 s.

# %%
# ============================================================
# (17) RESOLUÇÃO — MEÇA O TEMPO
# ============================================================
# Boa prática:
# Sempre registre tempo e status de solução.

# Pergunta:
# O tempo aumentou em relação à Aula 3? Por quê?

import time

start_time = time.time()
results = solver.solve(model)
end_time = time.time()

print("Status:", results.solver.status)
print("Termination:", results.solver.termination_condition)
print("Tempo:", end_time - start_time)
print("Custo total:", value(model.obj))

for k in model.K:
    print(f"Veículos tipo {k}:", value(model.y[k]))

# ===================================
# TODO (ALUNO): comente o MTZ e rode novamente.
# O que apareceu?
# ===================================
# Out:
# WARNING: Loading a SolverResults object with an 'aborted' status, but
# containing a solution
# Status: aborted
# Termination: maxTimeLimit
# Tempo: 60.17695498466492
# Custo total: 1351.9577566965013
# Veículos tipo FIO: 1.0
# Veículos tipo VUC: 1.0

# %%
# ============================================================
# (18) EXTRAÇÃO DOS ARCOS SELECIONADOS
# ============================================================
# Após resolver, extraímos os arcos (i,j,k) com x=1.

# Isso é a "solução" em linguagem do modelo.
# Agora precisamos convertê-la em rotas compreensíveis.

selected_arcs = [(i,j,k) for (i,j,k) in model.A
                 if value(model.x[i,j,k]) > 0.5]

print("Arcos selecionados:", selected_arcs[:20])
# Out:
# Arcos selecionados: [(0, 1, 'FIO'), (0, 13, 'VUC'), (1, 33, 'FIO'), (2, 21, 'VUC'), (3, 34, 'FIO'), (4, 25, 'FIO'), (5, 7, 'FIO'), (6, 2, 'VUC'), (7, 20, 'FIO'), (8, 36, 'VUC'), (9, 35, 'VUC'), (10, 3, 'FIO'), (11, 0, 'VUC'), (12, 18, 'VUC'), (13, 32, 'VUC'), (14, 29, 'VUC'), (15, 10, 'FIO'), (16, 28, 'FIO'), (17, 27, 'VUC'), (18, 26, 'VUC')]

# %%
# ============================================================
# (19) RECONSTRUÇÃO DAS ROTAS POR VEÍCULO
# ============================================================
# Transformamos a lista de arcos em sequência (rota) por veículo.
#
# Atenção:
# - este passo é pós-processamento (não é otimização)
# - é essencial para validar operacionalmente.

from collections import defaultdict

succ = defaultdict(dict)

for (i,j,k) in selected_arcs:
    succ[k][i] = j

routes = []

for k in model.K:
    starts = [j for (i,j,kk) in selected_arcs if i == 0 and kk == k]

    for start in starts:
        route = [0, start]
        current = start

        while current != 0:
            next_node = succ[k].get(current, None)
            if next_node is None:
                break
            route.append(next_node)
            current = next_node

        routes.append((k, route))

# %%
# ============================================================
# (20) VALIDAÇÃO PÓS-SOLUÇÃO — JORNADA POR VEÍCULO/ROTA
# ============================================================
# Como a jornada NÃO foi imposta no MIP,
# validamos aqui se cada rota/veículo respeita H = 8h.
#
# Tempo total da rota = (tempo de deslocamento) + (tempo de serviço)
# ============================================================

def route_time(route):
    # Tempo de deslocamento ao longo dos arcos da rota
    t_mov = 0.0
    for a in range(len(route) - 1):
        i = route[a]
        j = route[a+1]
        t_mov += T[i, j]

    # Tempo de serviço (somente clientes, exclui depósito)
    clients = [node for node in route if node != 0]
    t_serv = sum(s[i] for i in clients)

    return t_mov + t_serv, t_mov, t_serv, clients

print(f"Limite operacional (referência): H = {H:.2f} h\n")

violations = 0
all_visited = set()

for r_id, (k, r) in enumerate(routes, start=1):
    t_total, t_mov, t_serv, clients = route_time(r)
    all_visited.update(clients)

    status = "OK" if t_total <= H + 1e-6 else "VIOLA"
    if status == "VIOLA":
        violations += 1

    print(f"[{k}] Rota {r_id}: tempo total = {t_total:.2f} h (mov={t_mov:.2f}, serv={t_serv:.2f}) -> {status}")

print(f"\nTotal de rotas que violam H: {violations}")

# Checagem de atendimento (sanidade): todos os clientes aparecem em alguma rota?
missing = set(range(1, n)) - all_visited
if missing:
    print("\nATENÇÃO: Existem clientes que não apareceram nas rotas reconstruídas:", sorted(missing))
else:
    print("\nChecagem de atendimento: OK (todos os clientes aparecem nas rotas).")
# Out:
# Limite operacional (referência): H = 8.00 h
#
# [FIO] Rota 1: tempo total = 8.22 h (mov=3.97, serv=4.25) -> VIOLA
# [VUC] Rota 2: tempo total = 10.98 h (mov=5.23, serv=5.75) -> VIOLA
#
# Total de rotas que violam H: 2
#
# Checagem de atendimento: OK (todos os clientes aparecem nas rotas).

# %%
# Métricas simples da rota (interpretação da solução):
# 1) número de clientes atendidos nesta rota
# 2) tempo médio total por cliente
# 3) tempo médio de serviço por cliente
# 4) tempo médio de deslocamento por cliente
# 5) percentual do tempo em deslocamento (vs. serviço)
#
# Dicas:
# - clients é uma lista com os clientes atendidos nesta rota (sem o depósito).
# - cuidado com divisão por zero (rotas degeneradas).
# - percentual = (tempo_deslocamento / tempo_total) * 100
# ============================================================

#GABARITO:
n_clients = len(clients)

if n_clients > 0:
    avg_total = t_total / n_clients
    avg_serv  = t_serv  / n_clients
    avg_mov   = t_mov   / n_clients
    pct_mov   = 100.0 * (t_mov / t_total) if t_total > 1e-9 else 0.0
else:
    avg_total = avg_serv = avg_mov = 0.0
    pct_mov = 0.0

print(f"    Clientes atendidos: {n_clients}")
print(f"    Tempo médio total por cliente: {avg_total:.2f} h/cliente")
print(f"    Tempo médio de serviço por cliente: {avg_serv:.2f} h/cliente")
print(f"    Tempo médio de deslocamento por cliente: {avg_mov:.2f} h/cliente")
print(f"    % tempo em deslocamento: {pct_mov:.1f}%")
# Out:
#     Clientes atendidos: 23
#     Tempo médio total por cliente: 0.48 h/cliente
#     Tempo médio de serviço por cliente: 0.25 h/cliente
#     Tempo médio de deslocamento por cliente: 0.23 h/cliente
#     % tempo em deslocamento: 47.6%

# %%
# ============================================================
# (21) VISUALIZAÇÃO
# ============================================================
# É uma ferramenta de validação:
# - existe rota desconectada?
# - todos saem e retornam ao depósito?
# - MTZ funcionou (subtours desapareceram)?

# Antes de seguir, responda:
# Você consegue identificar algum ciclo sem depósito?

import matplotlib.pyplot as plt

x_coords = nodes["lon"].values
y_coords = nodes["lat"].values

plt.figure(figsize=(8,8))

plt.scatter(x_coords[1:], y_coords[1:], color='blue')
plt.scatter(x_coords[0], y_coords[0], color='red', s=150)

for k, route in routes:
  for i in range(len(route)-1):
        i_node = route[i]
        j_node = route[i+1]
        plt.plot([x_coords[i_node], x_coords[j_node]],
                 [y_coords[i_node], y_coords[j_node]])

plt.title("Rotas com MTZ + Frota Heterogênea")
plt.grid(True)
plt.show()

# %%
# ============================================================
# (22) CHECK OPERACIONAL (AGREGADO)
# ============================================================
# Aqui verificamos coerência operacional, mesmo que de forma agregada:
# - demanda total vs capacidade total ativada
# - tempos de deslocamento e serviço
# - orçamento de horas (H * veículos ativados)
#
# Mensagem-chave:
# Resolver MILP não encerra o trabalho. Operação precisa validar.

from pyomo.environ import value

total_demand = sum(q[i] for i in range(1,n))
cap_total = sum(Q[k]*value(model.y[k]) for k in vehicle_types)

Tmov_sol = sum(T[i,j]*value(model.x[i,j,k]) for (i,j,k) in model.A)
Tserv = sum(s[i] for i in range(1,n))

print("=== CHECK OPERACIONAL (AGREGADO) ===")
print(f"Demanda total (kg): {total_demand:.1f}")
print(f"Capacidade total disponível (kg): {cap_total:.1f}")
print(f"Tempo deslocamento da solução (h): {Tmov_sol:.2f}")
print(f"Tempo de serviço total (h): {Tserv:.2f}")
print(f"Tempo total (h): {Tmov_sol+Tserv:.2f}")
print("m[VUC] =", value(model.y["VUC"]), "| m[FIO] =", value(model.y["FIO"]))
print("Termination condition:", results.solver.termination_condition)
print("\nObs.: H=8h NÃO foi imposto no MIP. A jornada está sendo validada por rota/veículo.")
# Out:
# === CHECK OPERACIONAL (AGREGADO) ===
# Demanda total (kg): 863.1
# Capacidade total disponível (kg): 3650.0
# Tempo deslocamento da solução (h): 9.20
# Tempo de serviço total (h): 10.00
# Tempo total (h): 19.20
# m[VUC] = 1.0 | m[FIO] = 1.0
# Termination condition: maxTimeLimit
#
# Obs.: H=8h NÃO foi imposto no MIP. A jornada está sendo validada por rota/veículo.

# %%
# ============================================================
# (23) EXPERIMENTO COMPUTACIONAL CONTROLADO
# ============================================================
# Agora vamos impor um limite de tempo ao solver.
# Objetivo:
# - Observar como o solver retorna solução incumbente
# - Avaliar o gap
# - Entender o trade-off entre tempo e qualidade
# ============================================================

solver.options.clear()
USE_TIMELIMIT = True
TL_SECONDS = 300  # 5 minutos (ajuste se quiser)

if USE_TIMELIMIT:

    print(f"\nResolvendo com limite de {TL_SECONDS} segundos...\n")

    if SOLVER_NAME.startswith("gurobi_direct"):
        solver.options["TimeLimit"] = TL_SECONDS

    elif SOLVER_NAME.startswith("cplex"):
        solver.options["timelimit"] = TL_SECONDS

    elif SOLVER_NAME == "cbc":
        solver.options["seconds"] = TL_SECONDS

    import time
    start_time = time.time()
    results = solver.solve(model, tee=True)
    end_time = time.time()

    elapsed = end_time - start_time

    print("\nStatus:", results.solver.status)
    print("Termination condition:", results.solver.termination_condition)
    print(f"Tempo de solução: {elapsed:.2f} segundos")

    try:
        print("Custo incumbente:", value(model.obj))
    except:
        print("Nenhuma solução incumbente disponível.")
# Out:
# Resolvendo com limite de 300 segundos...
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - c:\Users\Anton\AppData\Local\Programs\Python\Python312\Lib\site-packages\pulp\solverdir\cbc\win\i64\cbc.exe -seconds 300 -printingOptions all -import C:\Users\Anton\AppData\Local\Temp\tmpj_oud7mh.pyomo.lp -stat=1 -solve -solu C:\Users\Anton\AppData\Local\Temp\tmpj_oud7mh.pyomo.soln (default strategy 1)
# seconds was changed from 1e+100 to 300
# Option for printingOptions changed from normal to all
# Presolve 1729 (0) rows, 3322 (0) columns and 19446 (0) elements
# Statistics for presolved model
# Original problem has 3282 integers (3282 of which binary)
# ==== 40 zero objective 823 different
# ==== absolute objective values 823 different
# ==== for integers 0 zero objective 822 different
# ==== for integers absolute objective values 822 different
# ===== end objective counts
#
#
# Problem has 1729 rows, 3322 columns (3282 with objective) and 19446 elements
# Column breakdown:
# 0 of type 0.0->inf, 0 of type 0.0->up, 0 of type lo->inf,
# 40 of type lo->up, 0 of type free, 0 of type fixed,
# 0 of type -inf->0.0, 0 of type -inf->up, 3282 of type 0.0->1.0
# Row breakdown:
# 82 of type E 0.0, 80 of type E 1.0, 0 of type E -1.0,
# 0 of type E other, 0 of type G 0.0, 0 of type G 1.0,
# 1 of type G other, 4 of type L 0.0, 2 of type L 1.0,
# 1560 of type L other, 0 of type Range 0.0->1.0, 0 of type Range other,
# 0 of type Free
# Continuous objective value is 296.411 - 0.01 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 1726 rows, 3321 columns (3281 integer (3281 of which binary)) and 19362 elements
# Cbc0038I Initial state - 84 integers unsatisfied sum - 2.35
# Cbc0038I Pass   1: suminf.    2.00000 (94) obj. 732.879 iterations 444
# Cbc0038I Pass   2: suminf.    2.92500 (35) obj. 1434.7 iterations 210
# Cbc0038I Pass   3: suminf.    2.00000 (50) obj. 1420.97 iterations 220
# Cbc0038I Pass   4: suminf.    2.50000 (26) obj. 1293.05 iterations 196
# Cbc0038I Pass   5: suminf.    2.00000 (50) obj. 1292.36 iterations 231
# Cbc0038I Pass   6: suminf.    2.57500 (27) obj. 1500.74 iterations 236
# Cbc0038I Pass   7: suminf.    2.00000 (50) obj. 1501.38 iterations 117
# Cbc0038I Pass   8: suminf.    2.22500 (46) obj. 1301.32 iterations 327
# Cbc0038I Pass   9: suminf.    2.00000 (53) obj. 1303.24 iterations 233
# Cbc0038I Pass  10: suminf.    2.00000 (29) obj. 1401.76 iterations 291
# Cbc0038I Pass  11: suminf.    2.00000 (42) obj. 1397.34 iterations 173
# Cbc0038I Pass  12: suminf.    2.00000 (52) obj. 1251.1 iterations 392
# Cbc0038I Pass  13: suminf.    2.00000 (55) obj. 1251.28 iterations 9
# Cbc0038I Pass  14: suminf.    2.00000 (66) obj. 1466.61 iterations 199
# Cbc0038I Pass  15: suminf.    2.00000 (41) obj. 1453.86 iterations 100
# Cbc0038I Pass  16: suminf.    2.00000 (36) obj. 1439.43 iterations 180
# Cbc0038I Pass  17: suminf.    2.00000 (55) obj. 1417.32 iterations 85
# Cbc0038I Pass  18: suminf.    2.08269 (45) obj. 1195.24 iterations 259
# Cbc0038I Pass  19: suminf.    2.00000 (53) obj. 1192.84 iterations 42
# Cbc0038I Pass  20: suminf.    2.00000 (33) obj. 1401.91 iterations 378
# Cbc0038I Pass  21: suminf.    2.00000 (36) obj. 1377.75 iterations 70
# Cbc0038I Pass  22: suminf.    2.25000 (18) obj. 1219.4 iterations 308
# Cbc0038I Pass  23: suminf.    2.00000 (55) obj. 1245.63 iterations 190
# Cbc0038I Pass  24: suminf.    2.00000 (29) obj. 1404.61 iterations 155
# Cbc0038I Pass  25: suminf.    2.00000 (44) obj. 1418.79 iterations 253
# Cbc0038I Pass  26: suminf.    2.18000 (24) obj. 1530.21 iterations 316
# Cbc0038I Pass  27: suminf.    2.00000 (32) obj. 1520.73 iterations 188
# Cbc0038I Pass  28: suminf.    2.00000 (46) obj. 1428.69 iterations 216
# Cbc0038I Pass  29: suminf.    2.00000 (30) obj. 1449.07 iterations 312
# Cbc0038I Pass  30: suminf.    3.30000 (17) obj. 1595.45 iterations 391
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 2938 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 472 rows 372 columns
# Cbc0038I Mini branch and bound did not improve solution (1.37 seconds)
# Cbc0038I Full problem 1727 rows 3321 columns, reduced to 1727 rows 3321 columns - too large
# Cbc0038I After 1.39 seconds - Feasibility pump exiting - took 1.23 seconds
# Cbc0031I 50 added rows had average density of 371.78
# Cbc0013I At root node, 50 cuts changed objective from 688.17316 to 722.3875 in 11 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.213 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 223 row cuts average 359.5 elements, 0 column cuts (0 active)  in 0.113 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 127 row cuts average 54.8 elements, 0 column cuts (0 active)  in 0.036 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.034 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 365 row cuts average 186.8 elements, 0 column cuts (0 active)  in 0.073 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 722.3875 (2.21 seconds)
# Cbc0004I Integer solution of 1377.9805 found after 2274 iterations and 96 nodes (3.50 seconds)
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 61 rows 47 columns
# Cbc0010I After 100 nodes, 66 on tree, 1377.9805 best solution, best possible 722.3875 (3.52 seconds)
# Cbc0016I Integer solution of 1365.5629 found by strong branching after 3080 iterations and 174 nodes (3.79 seconds)
# Cbc0016I Integer solution of 1353.4732 found by strong branching after 3171 iterations and 181 nodes (3.81 seconds)
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 38 rows 30 columns
# Cbc0010I After 200 nodes, 105 on tree, 1353.4732 best solution, best possible 722.3875 (3.90 seconds)
# Cbc0016I Integer solution of 1351.9578 found by strong branching after 3639 iterations and 222 nodes (3.99 seconds)
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 52 rows 41 columns
# Cbc0010I After 300 nodes, 129 on tree, 1351.9578 best solution, best possible 722.3875 (4.28 seconds)
# Cbc0010I After 400 nodes, 161 on tree, 1351.9578 best solution, best possible 722.3875 (4.63 seconds)
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 52 rows 41 columns
# Cbc0010I After 500 nodes, 195 on tree, 1351.9578 best solution, best possible 722.3875 (5.02 seconds)
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 55 rows 43 columns
# Cbc0010I After 600 nodes, 227 on tree, 1351.9578 best solution, best possible 722.3875 (5.35 seconds)
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 52 rows 40 columns
# Cbc0010I After 700 nodes, 266 on tree, 1351.9578 best solution, best possible 722.3875 (5.67 seconds)
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 32 rows 26 columns
# Cbc0010I After 800 nodes, 298 on tree, 1351.9578 best solution, best possible 722.3875 (6.00 seconds)
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 43 rows 35 columns
# Cbc0010I After 900 nodes, 320 on tree, 1351.9578 best solution, best possible 722.3875 (6.36 seconds)
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 53 rows 40 columns
# Cbc0010I After 1000 nodes, 356 on tree, 1351.9578 best solution, best possible 722.3875 (6.71 seconds)
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 95 rows 53 columns
# Cbc0010I After 1100 nodes, 454 on tree, 1351.9578 best solution, best possible 722.3875 (7.54 seconds)
# Cbc0010I After 1200 nodes, 501 on tree, 1351.9578 best solution, best possible 722.3875 (7.99 seconds)
# Cbc0010I After 1300 nodes, 503 on tree, 1351.9578 best solution, best possible 722.3875 (8.42 seconds)
# Cbc0010I After 1400 nodes, 501 on tree, 1351.9578 best solution, best possible 722.3875 (8.77 seconds)
# Cbc0010I After 1500 nodes, 510 on tree, 1351.9578 best solution, best possible 722.3875 (9.21 seconds)
# Cbc0010I After 1600 nodes, 500 on tree, 1351.9578 best solution, best possible 722.3875 (9.64 seconds)
# Cbc0010I After 1700 nodes, 524 on tree, 1351.9578 best solution, best possible 722.3875 (10.05 seconds)
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 122 rows 67 columns
# Cbc0010I After 1800 nodes, 518 on tree, 1351.9578 best solution, best possible 722.3875 (10.42 seconds)
# Cbc0010I After 1900 nodes, 516 on tree, 1351.9578 best solution, best possible 722.3875 (10.77 seconds)
# Cbc0010I After 2000 nodes, 512 on tree, 1351.9578 best solution, best possible 722.3875 (11.17 seconds)
# Cbc0010I After 2100 nodes, 517 on tree, 1351.9578 best solution, best possible 722.3875 (11.54 seconds)
# Cbc0010I After 2200 nodes, 514 on tree, 1351.9578 best solution, best possible 722.3875 (11.93 seconds)
# Cbc0010I After 2300 nodes, 516 on tree, 1351.9578 best solution, best possible 722.3875 (12.31 seconds)
# Cbc0010I After 2400 nodes, 511 on tree, 1351.9578 best solution, best possible 722.3875 (12.67 seconds)
# Cbc0010I After 2500 nodes, 518 on tree, 1351.9578 best solution, best possible 722.3875 (13.09 seconds)
# Cbc0010I After 2600 nodes, 510 on tree, 1351.9578 best solution, best possible 722.3875 (13.54 seconds)
# Cbc0010I After 2700 nodes, 514 on tree, 1351.9578 best solution, best possible 722.3875 (14.04 seconds)
# Cbc0010I After 2800 nodes, 514 on tree, 1351.9578 best solution, best possible 722.3875 (14.50 seconds)
# Cbc0010I After 2900 nodes, 505 on tree, 1351.9578 best solution, best possible 722.3875 (14.91 seconds)
# Cbc0010I After 3000 nodes, 521 on tree, 1351.9578 best solution, best possible 722.3875 (15.31 seconds)
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 90 rows 51 columns
# Cbc0010I After 3100 nodes, 512 on tree, 1351.9578 best solution, best possible 722.3875 (15.71 seconds)
# Cbc0010I After 3200 nodes, 512 on tree, 1351.9578 best solution, best possible 722.3875 (16.15 seconds)
# Cbc0010I After 3300 nodes, 507 on tree, 1351.9578 best solution, best possible 722.3875 (16.50 seconds)
# Cbc0010I After 3400 nodes, 516 on tree, 1351.9578 best solution, best possible 722.3875 (16.87 seconds)
# Cbc0010I After 3500 nodes, 513 on tree, 1351.9578 best solution, best possible 722.3875 (17.20 seconds)
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 91 rows 52 columns
# Cbc0010I After 3600 nodes, 520 on tree, 1351.9578 best solution, best possible 722.3875 (17.52 seconds)
# Cbc0010I After 3700 nodes, 523 on tree, 1351.9578 best solution, best possible 722.3875 (17.90 seconds)
# Cbc0010I After 3800 nodes, 524 on tree, 1351.9578 best solution, best possible 722.3875 (18.24 seconds)
# Cbc0010I After 3900 nodes, 514 on tree, 1351.9578 best solution, best possible 722.3875 (18.59 seconds)
# Cbc0010I After 4000 nodes, 519 on tree, 1351.9578 best solution, best possible 722.3875 (18.94 seconds)
# Cbc0010I After 4100 nodes, 514 on tree, 1351.9578 best solution, best possible 722.3875 (19.30 seconds)
# Cbc0010I After 4200 nodes, 511 on tree, 1351.9578 best solution, best possible 722.3875 (19.64 seconds)
# Cbc0010I After 4300 nodes, 507 on tree, 1351.9578 best solution, best possible 722.3875 (19.98 seconds)
# Cbc0010I After 4400 nodes, 511 on tree, 1351.9578 best solution, best possible 722.3875 (20.32 seconds)
# Cbc0010I After 4500 nodes, 508 on tree, 1351.9578 best solution, best possible 722.3875 (20.70 seconds)
# Cbc0010I After 4600 nodes, 502 on tree, 1351.9578 best solution, best possible 722.3875 (21.12 seconds)
# Cbc0010I After 4700 nodes, 504 on tree, 1351.9578 best solution, best possible 722.3875 (21.43 seconds)
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 101 rows 56 columns
# Cbc0010I After 4800 nodes, 502 on tree, 1351.9578 best solution, best possible 722.3875 (21.81 seconds)
# Cbc0010I After 4900 nodes, 504 on tree, 1351.9578 best solution, best possible 722.3875 (22.10 seconds)
# Cbc0010I After 5000 nodes, 510 on tree, 1351.9578 best solution, best possible 722.3875 (22.45 seconds)
# Cbc0010I After 5100 nodes, 607 on tree, 1351.9578 best solution, best possible 722.3875 (22.98 seconds)
# Cbc0010I After 5200 nodes, 602 on tree, 1351.9578 best solution, best possible 722.3875 (23.48 seconds)
# Cbc0010I After 5300 nodes, 606 on tree, 1351.9578 best solution, best possible 722.3875 (23.85 seconds)
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 90 rows 52 columns
# Cbc0010I After 5400 nodes, 605 on tree, 1351.9578 best solution, best possible 722.3875 (24.23 seconds)
# Cbc0010I After 5500 nodes, 606 on tree, 1351.9578 best solution, best possible 722.3875 (24.57 seconds)
# Cbc0010I After 5600 nodes, 602 on tree, 1351.9578 best solution, best possible 722.3875 (24.90 seconds)
# Cbc0010I After 5700 nodes, 603 on tree, 1351.9578 best solution, best possible 722.3875 (25.29 seconds)
# Cbc0010I After 5800 nodes, 604 on tree, 1351.9578 best solution, best possible 722.3875 (25.62 seconds)
# Cbc0010I After 5900 nodes, 609 on tree, 1351.9578 best solution, best possible 722.3875 (25.96 seconds)
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 89 rows 51 columns
# Cbc0010I After 6000 nodes, 603 on tree, 1351.9578 best solution, best possible 722.3875 (26.33 seconds)
# Cbc0010I After 6100 nodes, 598 on tree, 1351.9578 best solution, best possible 722.3875 (26.74 seconds)
# Cbc0010I After 6200 nodes, 601 on tree, 1351.9578 best solution, best possible 722.3875 (27.13 seconds)
# Cbc0010I After 6300 nodes, 597 on tree, 1351.9578 best solution, best possible 722.3875 (27.46 seconds)
# Cbc0010I After 6400 nodes, 600 on tree, 1351.9578 best solution, best possible 722.3875 (27.78 seconds)
# Cbc0010I After 6500 nodes, 595 on tree, 1351.9578 best solution, best possible 722.3875 (28.12 seconds)
# Cbc0010I After 6600 nodes, 600 on tree, 1351.9578 best solution, best possible 722.3875 (28.42 seconds)
# Cbc0010I After 6700 nodes, 603 on tree, 1351.9578 best solution, best possible 722.3875 (28.74 seconds)
# Cbc0010I After 6800 nodes, 602 on tree, 1351.9578 best solution, best possible 722.3875 (29.13 seconds)
# Cbc0010I After 6900 nodes, 599 on tree, 1351.9578 best solution, best possible 722.3875 (29.51 seconds)
# Cbc0010I After 7000 nodes, 597 on tree, 1351.9578 best solution, best possible 722.3875 (29.90 seconds)
# Cbc0010I After 7100 nodes, 597 on tree, 1351.9578 best solution, best possible 722.3875 (30.26 seconds)
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 82 rows 47 columns
# Cbc0010I After 7200 nodes, 603 on tree, 1351.9578 best solution, best possible 722.3875 (30.66 seconds)
# Cbc0010I After 7300 nodes, 607 on tree, 1351.9578 best solution, best possible 722.3875 (30.98 seconds)
# Cbc0010I After 7400 nodes, 602 on tree, 1351.9578 best solution, best possible 722.3875 (31.33 seconds)
# Cbc0010I After 7500 nodes, 607 on tree, 1351.9578 best solution, best possible 722.3875 (31.71 seconds)
# Cbc0010I After 7600 nodes, 598 on tree, 1351.9578 best solution, best possible 722.3875 (32.03 seconds)
# Cbc0010I After 7700 nodes, 597 on tree, 1351.9578 best solution, best possible 722.3875 (32.32 seconds)
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 89 rows 51 columns
# Cbc0010I After 7800 nodes, 595 on tree, 1351.9578 best solution, best possible 722.3875 (32.72 seconds)
# Cbc0010I After 7900 nodes, 596 on tree, 1351.9578 best solution, best possible 722.3875 (33.05 seconds)
# Cbc0010I After 8000 nodes, 596 on tree, 1351.9578 best solution, best possible 722.3875 (33.36 seconds)
# Cbc0010I After 8100 nodes, 592 on tree, 1351.9578 best solution, best possible 722.3875 (33.69 seconds)
# Cbc0010I After 8200 nodes, 602 on tree, 1351.9578 best solution, best possible 722.3875 (34.08 seconds)
# Cbc0010I After 8300 nodes, 599 on tree, 1351.9578 best solution, best possible 722.3875 (34.53 seconds)
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 82 rows 49 columns
# Cbc0010I After 8400 nodes, 599 on tree, 1351.9578 best solution, best possible 722.3875 (34.98 seconds)
# Cbc0010I After 8500 nodes, 609 on tree, 1351.9578 best solution, best possible 722.3875 (35.36 seconds)
# Cbc0010I After 8600 nodes, 611 on tree, 1351.9578 best solution, best possible 722.3875 (35.79 seconds)
# Cbc0010I After 8700 nodes, 612 on tree, 1351.9578 best solution, best possible 722.3875 (36.18 seconds)
# Cbc0010I After 8800 nodes, 606 on tree, 1351.9578 best solution, best possible 722.3875 (36.54 seconds)
# Cbc0010I After 8900 nodes, 606 on tree, 1351.9578 best solution, best possible 722.3875 (36.85 seconds)
# Cbc0010I After 9000 nodes, 608 on tree, 1351.9578 best solution, best possible 722.3875 (37.23 seconds)
# Cbc0010I After 9100 nodes, 705 on tree, 1351.9578 best solution, best possible 722.3875 (37.83 seconds)
# Cbc0010I After 9200 nodes, 754 on tree, 1351.9578 best solution, best possible 722.3875 (38.27 seconds)
# Cbc0010I After 9300 nodes, 747 on tree, 1351.9578 best solution, best possible 722.3875 (38.62 seconds)
# Cbc0010I After 9400 nodes, 748 on tree, 1351.9578 best solution, best possible 722.3875 (39.04 seconds)
# Cbc0010I After 9500 nodes, 748 on tree, 1351.9578 best solution, best possible 722.3875 (39.48 seconds)
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 83 rows 48 columns
# Cbc0010I After 9600 nodes, 745 on tree, 1351.9578 best solution, best possible 722.3875 (39.85 seconds)
# Cbc0010I After 9700 nodes, 743 on tree, 1351.9578 best solution, best possible 722.3875 (40.25 seconds)
# Cbc0010I After 9800 nodes, 747 on tree, 1351.9578 best solution, best possible 722.3875 (40.75 seconds)
# Cbc0010I After 9900 nodes, 745 on tree, 1351.9578 best solution, best possible 722.3875 (41.18 seconds)
# Cbc0010I After 10000 nodes, 754 on tree, 1351.9578 best solution, best possible 722.3875 (41.59 seconds)
# Cbc0010I After 10100 nodes, 751 on tree, 1351.9578 best solution, best possible 722.3875 (41.94 seconds)
# Cbc0010I After 10200 nodes, 750 on tree, 1351.9578 best solution, best possible 722.3875 (42.24 seconds)
# Cbc0010I After 10300 nodes, 750 on tree, 1351.9578 best solution, best possible 722.3875 (42.59 seconds)
# Cbc0010I After 10400 nodes, 747 on tree, 1351.9578 best solution, best possible 722.3875 (42.97 seconds)
# Cbc0010I After 10500 nodes, 743 on tree, 1351.9578 best solution, best possible 722.3875 (43.44 seconds)
# Cbc0010I After 10600 nodes, 747 on tree, 1351.9578 best solution, best possible 722.3875 (43.83 seconds)
# Cbc0010I After 10700 nodes, 740 on tree, 1351.9578 best solution, best possible 722.3875 (44.19 seconds)
# Cbc0038I Full problem 1726 rows 3321 columns, reduced to 94 rows 53 columns
# Cbc0010I After 10800 nodes, 749 on tree, 1351.9578 best solution, best possible 722.3875 (44.61 seconds)
# Cbc0010I After 10900 nodes, 749 on tree, 1351.9578 best solution, best possible 722.3875 (44.94 seconds)
# Cbc0010I After 11000 nodes, 739 on tree, 1351.9578 best solution, best possible 722.3875 (45.37 seconds)
# Cbc0010I After 11100 nodes, 785 on tree, 1351.9578 best solution, best possible 723.62265 (48.15 seconds)
# Cbc0010I After 11200 nodes, 834 on tree, 1351.9578 best solution, best possible 724.1347 (49.56 seconds)
# Cbc0010I After 11300 nodes, 883 on tree, 1351.9578 best solution, best possible 724.44244 (50.80 seconds)
# Cbc0010I After 11400 nodes, 934 on tree, 1351.9578 best solution, best possible 724.54785 (52.01 seconds)
# Cbc0010I After 11500 nodes, 983 on tree, 1351.9578 best solution, best possible 724.58639 (52.89 seconds)
# Cbc0010I After 11600 nodes, 1034 on tree, 1351.9578 best solution, best possible 724.61857 (53.87 seconds)
# Cbc0010I After 11700 nodes, 1084 on tree, 1351.9578 best solution, best possible 724.65057 (54.92 seconds)
# Cbc0010I After 11800 nodes, 1133 on tree, 1351.9578 best solution, best possible 724.6787 (55.94 seconds)
# Cbc0010I After 11900 nodes, 1184 on tree, 1351.9578 best solution, best possible 724.7008 (56.91 seconds)
# Cbc0010I After 12000 nodes, 1233 on tree, 1351.9578 best solution, best possible 724.70876 (57.84 seconds)
# Cbc0010I After 12100 nodes, 1283 on tree, 1351.9578 best solution, best possible 724.73565 (58.98 seconds)
# Cbc0010I After 12200 nodes, 1334 on tree, 1351.9578 best solution, best possible 724.75086 (59.85 seconds)
# Cbc0010I After 12300 nodes, 1383 on tree, 1351.9578 best solution, best possible 724.76254 (60.90 seconds)
# Cbc0010I After 12400 nodes, 1434 on tree, 1351.9578 best solution, best possible 724.77806 (62.01 seconds)
